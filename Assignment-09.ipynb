# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception

# %% [markdown]
# we have to inherit the Exception class in our custom Exception class to inherit the properties and functionality of the Exception class so that we can display our custom error message through the custom class

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# import inspect module
import inspect
  
# our treeClass function
def Hierarchy(cls, ind = 0):
    
      # print name of the class
    print ('-' * ind, cls.__name__)
      
    # iterating through subclasses
    for i in cls.__subclasses__():
        Hierarchy(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
  
# building a Hierarchy
inspect.getclasstree(inspect.getmro(BaseException))
  
# function call
Hierarchy(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# ------------ PackageNotFoundError
# ------------ PackageNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- herror
# --------- gaierror
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# ArithmeticError is simply an error that occurs during numeric calculations.
# ArithmeticError types in Python include:
#
# 1.OverFlowError
# 2.ZeroDivisionError

# %%
# overflow error

try: 
    n = 8.0
    for i in range(1, 100):
        n = n ** i
        print("For i=%d, n=%f" %(i, n))
except OverflowError as e:
    print(e)
# Out:
# For i=1, n=8.000000
# For i=2, n=64.000000
# For i=3, n=262144.000000
# For i=4, n=4722366482869645213696.000000
# For i=5, n=2348542582773833227889480596789337027375682548908319870707290971532209025114608443463698998384768703031934976.000000
# (34, 'Result too large')

# %%
# zerodivision error

try:
    num = 456/0
    print("error")
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.
#
# we can use LookupError exception class to handle both IndexError and KeyError exception classes.

# %%
# Handling IndexError exception

x = [1, 2, 3, 4]
try:
    print(x[10])
except LookupError as e:
    print(f"{e}, {e.__class__}")
# Out:
# list index out of range, <class 'IndexError'>

# %%
# Handling KeyError exception

data_info = {'name': 'TUSHAR SINGH',
             'age': 21,
             'language': 'Python'}
user_input = input('What do you want to learn about data_info==> ')

try:
    print(f'{user_input} is {data_info[user_input]}')
except LookupError as e:
    print(f'{e}, {e.__class__}')
# Out:
# What do you want to learn about data_info==> gender
# 'gender', <class 'KeyError'>

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# Python's ImportError ( ModuleNotFoundError ) indicates that you tried to import a module that Python doesn't find. It can usually be eliminated by adding a file named __init__.py to the directory and then adding this directory to "$PYTHONPATH" .

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# 1. Use a specific exception
# 2. Use a proper error message
# 3. Always try to logg the error in our program
# 4. Always try to put the specific exception at the top and Exception superclass at last
# 5. Avoid multiple exception handling
# 6. Document all errors in logg and clean up all the resources after the are used
